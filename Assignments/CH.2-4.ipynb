# %% [markdown]
# # Ch. 2

# %% [markdown]
# ### Q. 1

# %% [markdown]
# a. Flexible will be better. the flixible ones will be more able to fit the data given a large number of data. The inflexible ones will be worse due to the lack of predictors
#
# b. Inflexible ones will be better. The flexible ones will overfit the small amount of data, result in high variance
#
# c. flexibla models will be better. Inflexible ones with fewer parameters can't capture the non-linear relationship of the data as good as flexible ones
#
# d. doesn't matter, as the error comes from incomplete information from the data, thus cannot be reduced

# %% [markdown]
# ### Q. 8

# %%
library(ISLR)
names(College)
head(College)

College[,0]
summary(College)

pairs(College[,1:10])
plot(College$Private, College$Outstate)
# Out:
#  [1] "Private"     "Apps"        "Accept"      "Enroll"      "Top10perc"
#  [6] "Top25perc"   "F.Undergrad" "P.Undergrad" "Outstate"    "Room.Board"
# [11] "Books"       "Personal"    "PhD"         "Terminal"    "S.F.Ratio"
# [16] "perc.alumni" "Expend"      "Grad.Rate"
#                              Private Apps Accept Enroll Top10perc Top25perc
# Abilene Christian University Yes     1660 1232   721    23        52
# Adelphi University           Yes     2186 1924   512    16        29
# Adrian College               Yes     1428 1097   336    22        50
# Agnes Scott College          Yes      417  349   137    60        89
# Alaska Pacific University    Yes      193  146    55    16        44
# Albertson College            Yes      587  479   158    38        62
#                              F.Undergrad P.Undergrad Outstate Room.Board Books
# Abilene Christian University 2885         537         7440    3300       450
# ...

# %%
Elite=rep('No', nrow(College))
Elite[College$Top10perc>50]="Yes"
Elite=as.factor(Elite)
dim(Elite)

# %%
college=data.frame(College, Elite)
summary(college)

plot(college$Elite, college$Outstate)

# %%
par(mfrow=c(2,2))
hist(college$P.Undergrad, breaks=50, xlim=c(0, 10000))
hist(college$F.Undergrad)
hist(college$S.F.Ratio)
hist(college$PhD)
# Out:
# Plot with title “Histogram of college$PhD”

# %%
par(mfrow=c(1,2))
plot(college$Elite, college$PhD)
# most elite schools have a lot of phd
plot(college$F.Undergrad, college$Expend)
# the less the f.undergrad, the more the expend it seems
# Out:
# plot without title

# %% [markdown]
# ### Q.10

# %%
library(MASS)
Boston
?Boston
boston = Boston
attach(boston)
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
pairs(Boston)
# crim correlates with age, dis, rad, lstat, medv
# zn correlates with indus, nox, age, lstat### Q. 8
# indus correlates with age, dis


par(mfrow=c(2,2))
plot(Boston$dis, Boston$nox)
# seems the farther it is away from the center, the lower the NO concentration
plot(Boston$rm, Boston$medv)
# more owner occupied homes, more rooms per dwelling
plot(Boston$lstat, Boston$medv)
# the more lower status population, the less mean value of owerner-occupied homes
plot(Boston$rad, Boston$dis)
# the farther away, the less highway accessible

par(mfrow=c(2,3))
# age, dis, rad, lstat, medv, ptratio all have different level of correlations with crime rate
plot(age, crim)
plot(dis, crim)
plot(rad, crim)
plot(lstat, crim)
plot(medv, crim)
plot(ptratio, crim)
# Out:
# plot without title

# %%
par(mfrow=c(1,3))
hist(crim[crim>.5], breaks=20, ylim=c(0, 30))
# few suburbs have higher crime rates
hist(tax, breaks=20)
# a bunch of suburbs have very high tax (>600)
hist(ptratio[ptratio>15], breaks=20)
# many has high ptratio
# Out:
# Plot with title “Histogram of ptratio[ptratio > 15]”

# %%
sum(chas==1)
median(ptratio)
subset(boston, medv == min(medv))
summary(boston)
# crime rates are above the 3rd qu.
# indus at 3rd qu.
# dis are below the first qu.
# lstat are above the 3rd qu.
# medv are at min
# Out:
# [1] 35
# [1] 19.05
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio black  lstat
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    396.90 30.59
# 406 67.9208 0  18.1  0    0.693 5.683 100 1.4254 24  666 20.2    384.97 22.98
#     medv
# 399 5
# 406 5
# [1]  0.00632 88.97620
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
# ...

# %%
dim(subset(boston, rm > 8))
dim(subset(boston, rm > 7))
subset(boston, rm > 8)
# lstat are mostly lower than the first qu.
# medv are mostly higher than 3rd. qu
# crime rate are lower than median
# Out:
# [1] 13 14
# [1] 64 14
#     crim    zn indus chas nox    rm    age  dis    rad tax ptratio black  lstat
# 98  0.12083  0  2.89 0    0.4450 8.069 76.0 3.4952  2  276 18.0    396.90 4.21
# 164 1.51902  0 19.58 1    0.6050 8.375 93.9 2.1620  5  403 14.7    388.45 3.32
# 205 0.02009 95  2.68 0    0.4161 8.034 31.9 5.1180  4  224 14.7    390.55 2.88
# 225 0.31533  0  6.20 0    0.5040 8.266 78.3 2.8944  8  307 17.4    385.05 4.14
# 226 0.52693  0  6.20 0    0.5040 8.725 83.0 2.8944  8  307 17.4    382.00 4.63
# 227 0.38214  0  6.20 0    0.5040 8.040 86.5 3.2157  8  307 17.4    387.38 3.13
# 233 0.57529  0  6.20 0    0.5070 8.337 73.3 3.8384  8  307 17.4    385.91 2.47
# 234 0.33147  0  6.20 0    0.5070 8.247 70.4 3.6519  8  307 17.4    378.95 3.95
# 254 0.36894 22  5.86 0    0.4310 8.259  8.4 8.9067  7  330 19.1    396.90 3.54
# 258 0.61154 20  3.97 0    0.6470 8.704 86.9 1.8010  5  264 13.0    389.70 5.12
# 263 0.52014 20  3.97 0    0.6470 8.398 91.5 2.2885  5  264 13.0    386.86 5.91
# ...

# %%
detach(boston)

# %% [markdown]
# # Ch. 3

# %% [markdown]
# ### Q.1

# %% [markdown]
# The null hypothesis of all three TV, radio and news paper is that they have no impact on sales (i.e. their coefficients are 0)
#
# TV and radio showed statistical significance, while news paper doesn't, so accept the null hypothesis of news papers coefficient == 0, which means news paper doesn't have impact on sales, while the two others have.
#
# Reject null hypothesis for TV and radio
#
# => under certain amount of ad on radio and newspaper, increase 1000 on ad of TV, get 46 more unit sales
#
# => under certain amount of ad on TV and newspaper, increase 1000 on ad of TV, get 189 more unit sales

# %% [markdown]
# ### Q.5

# %% [markdown]
# <img src="ch3_q5.png" width="400" height="400">

# %% [markdown]
# ### Q.8

# %%
auto = Auto
attach(auto)
summary(auto)
lm.fit = lm(mpg~horsepower, data=auto)
summary(lm.fit)
# Out:
# The following objects are masked from auto (pos = 3):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#
# The following objects are masked from auto (pos = 4):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#
# The following objects are masked from auto (pos = 5):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#
# The following objects are masked from auto (pos = 6):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
# ...

# %% [markdown]
# i. p value for both coef and horsepower are smaller than 0.001, so reject null hypothesis. p value for f test is small as well, we can reject the null hypothesis. horsepower and mpg has strong relations
#
# ii.
#
# iii. the relaiton is negative.
#
# iv. the predicted value is 24.467. interval as shown below

# %%
predict(lm.fit, data.frame(horsepower = (c(98))), interval = "confidence")
predict(lm.fit, data.frame(horsepower = (c(98))), interval = "prediction")
# Out:
#        1
# 24.46708
#   fit      lwr      upr
# 1 24.46708 23.97308 24.96108
#   fit      lwr     upr
# 1 24.46708 14.8094 34.12476

# %%
plot(horsepower, mpg)
abline(lm.fit, col = "blue")
# Out:
# plot without title

# %%
par(mfrow=c(2,2))
plot(lm.fit)
# judging from residual vs fitted plot, there is evidence of non linearity
# Out:
# Plot with title “”

# %% [markdown]
# ### Q.9

# %%
pairs(auto)
df = subset(auto, select = -c(name) )
cor(df)
# Out:
#              mpg        cylinders  displacement horsepower weight
# mpg           1.0000000 -0.7776175 -0.8051269   -0.7784268 -0.8322442
# cylinders    -0.7776175  1.0000000  0.9508233    0.8429834  0.8975273
# displacement -0.8051269  0.9508233  1.0000000    0.8972570  0.9329944
# horsepower   -0.7784268  0.8429834  0.8972570    1.0000000  0.8645377
# weight       -0.8322442  0.8975273  0.9329944    0.8645377  1.0000000
# acceleration  0.4233285 -0.5046834 -0.5438005   -0.6891955 -0.4168392
# year          0.5805410 -0.3456474 -0.3698552   -0.4163615 -0.3091199
# origin        0.5652088 -0.5689316 -0.6145351   -0.4551715 -0.5850054
#              acceleration year       origin
# mpg           0.4233285    0.5805410  0.5652088
# cylinders    -0.5046834   -0.3456474 -0.5689316
# displacement -0.5438005   -0.3698552 -0.6145351
# horsepower   -0.6891955   -0.4163615 -0.4551715
# weight       -0.4168392   -0.3091199 -0.5850054
# acceleration  1.0000000    0.2903161  0.2127458
# ...

# %%
lm.fit2 = lm(mpg~.-name, data=auto)
summary(lm.fit)
# Out:
# Call:
# lm(formula = mpg ~ cylinders + displacement + horsepower + weight +
#     acceleration + year + origin, data = auto)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.5903 -2.1565 -0.1169  1.8690 13.0604
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -17.218435   4.644294  -3.707  0.00024 ***
# cylinders     -0.493376   0.323282  -1.526  0.12780
# displacement   0.019896   0.007515   2.647  0.00844 **
# horsepower    -0.016951   0.013787  -1.230  0.21963
# weight        -0.006474   0.000652  -9.929  < 2e-16 ***
# acceleration   0.080576   0.098845   0.815  0.41548
# year           0.750773   0.050973  14.729  < 2e-16 ***
# origin         1.426141   0.278136   5.127 4.67e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.328 on 384 degrees of freedom
# Multiple R-squared:  0.8215,	Adjusted R-squared:  0.8182
# F-statistic: 252.4 on 7 and 384 DF,  p-value: < 2.2e-16

# %% [markdown]
# c. i. yes there is. The p-value of f test is close to zero, showing strong relations
#
# c. ii. weight and year and origin has statistically significant relationship
#
# c. iii. it suggests for 1 unit increase in year, the mpg will on average
# increase by 0.751

# %%
par(mfrow=c(2,2))
plot(lm.fit2)
# the residual vs fitted plot suggest variance of residuals increase as fitted value increases. 
# there is a curve of the plot
# there isn't obvious outliers, but from the residual vs leverage plot, these is a point having high leverage
# Out:
# Plot with title “”

# %%
lm.fit3 = lm(mpg~cylinders:displacement+ cylinders*horsepower)
summary(lm.fit3)
# both cylinders:displacement and cylinders:horsepower shows statistical significance
# Out:
# Call:
# lm(formula = mpg ~ cylinders:displacement + cylinders * horsepower)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -11.6039  -2.2381  -0.5215   2.0523  16.9269
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            70.221781   3.100397  22.649  < 2e-16 ***
# cylinders              -5.518402   0.566095  -9.748  < 2e-16 ***
# horsepower             -0.444198   0.034792 -12.767  < 2e-16 ***
# cylinders:displacement -0.004478   0.001201  -3.730  0.00022 ***
# cylinders:horsepower    0.056388   0.005261  10.718  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.027 on 387 degrees of freedom
# Multiple R-squared:  0.7365,	Adjusted R-squared:  0.7338
# F-statistic: 270.4 on 4 and 387 DF,  p-value: < 2.2e-16

# %%
lm.fit4 = lm(mpg~log(year) + I(origin^2)+sqrt(horsepower)+acceleration+I(acceleration^2))
summary(lm.fit4)
par(mfrow=c(2,2))
plot(lm.fit4)
# all predictors shows statitical significance. But residuals plot shows high variance
# Out:
# Call:
# lm(formula = mpg ~ log(year) + I(origin^2) + sqrt(horsepower) +
#     acceleration + I(acceleration^2))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.015  -2.134  -0.352   1.829  12.707
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -123.43953   17.96544  -6.871 2.57e-11 ***
# log(year)           50.35841    3.96160  12.712  < 2e-16 ***
# I(origin^2)          0.49941    0.06299   7.929 2.40e-14 ***
# sqrt(horsepower)    -3.53040    0.16372 -21.564  < 2e-16 ***
# acceleration        -4.03610    0.53874  -7.492 4.68e-13 ***
# I(acceleration^2)    0.10260    0.01598   6.421 3.99e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.453 on 386 degrees of freedom
# Multiple R-squared:  0.8068,	Adjusted R-squared:  0.8043
# F-statistic: 322.4 on 5 and 386 DF,  p-value: < 2.2e-16
# Plot with title “”

# %% [markdown]
# # Ch. 4

# %% [markdown]
# ### Q.1

# %% [markdown]
# <img src="ch4_q1.png" width="400" height="400">

# %% [markdown]
# ### Q.2

# %%
weekly = Weekly
attach(weekly)
head(weekly)
??weekly
# Out:
# The following objects are masked from weekly (pos = 3):
#
#     Direction, Lag1, Lag2, Lag3, Lag4, Lag5, Today, Volume, Year
#
# The following objects are masked from weekly (pos = 4):
#
#     Direction, Lag1, Lag2, Lag3, Lag4, Lag5, Today, Volume, Year
#
# The following objects are masked from weekly (pos = 5):
#
#     Direction, Lag1, Lag2, Lag3, Lag4, Lag5, Today, Volume, Year
#
# The following objects are masked from weekly (pos = 6):
#
#     Direction, Lag1, Lag2, Lag3, Lag4, Lag5, Today, Volume, Year
#   Year Lag1   Lag2   Lag3   Lag4   Lag5   Volume    Today  Direction
# 1 1990  0.816  1.572 -3.936 -0.229 -3.484 0.1549760 -0.270 Down
# 2 1990 -0.270  0.816  1.572 -3.936 -0.229 0.1485740 -2.576 Down
# 3 1990 -2.576 -0.270  0.816  1.572 -3.936 0.1598375  3.514 Up
# 4 1990  3.514 -2.576 -0.270  0.816  1.572 0.1616300  0.712 Up
# 5 1990  0.712  3.514 -2.576 -0.270  0.816 0.1537280  1.178 Up
# 6 1990  1.178  0.712  3.514 -2.576 -0.270 0.1544440 -1.372 Down

# %%
pairs(weekly)
# year and volume seems to follow some function like log
# graph is the same for each pair of lags 
plot(Lag1, Lag2)
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### Q.3

# %% [markdown]
# ### Q.10

# %% [markdown]
# ### Q.11
